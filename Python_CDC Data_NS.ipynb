# %% [markdown]
# # Below I've imported the data and programs

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("http://chronicdata.cdc.gov/api/views/g4ie-h725/rows.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # I've used .head, .tail, and .describe to get a better view of what data is being pulled

# %%
df.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2010     2014           WA   Washington
# 1       2009     2013           OR       Oregon
# 2       2009     2013           FL      Florida
# 3       2010     2014           MI     Michigan
# 4       2010     2014           KY     Kentucky
#
#                             DataSource   Topic  \
# 0                    Death Certificate  Cancer
# 1  Statewide central cancer registries  Cancer
# 2                    Death Certificate  Cancer
# 3  Statewide central cancer registries  Cancer
# 4  Statewide central cancer registries  Cancer
#
#                                             Question  Response DataValueUnit  \
# 0  Cancer of the colon and rectum (colorectal), m...       NaN   per 100,000
# 1    Invasive cancer (all sites combined), incidence       NaN   per 100,000
# 2   Cancer of the oral cavity and pharynx, mortality       NaN   per 100,000
# ...

# %%
df.tail()
# Out:
#         YearStart  YearEnd LocationAbbr          LocationDesc  \
# 814932       2009     2013           NM            New Mexico
# 814933       2009     2013           AL               Alabama
# 814934       2010     2014           OH                  Ohio
# 814935       2009     2013           SC        South Carolina
# 814936       2009     2013           DC  District of Columbia
#
#                                  DataSource   Topic  \
# 814932                    Death Certificate  Cancer
# 814933  Statewide central cancer registries  Cancer
# 814934                    Death Certificate  Cancer
# 814935                    Death Certificate  Cancer
# 814936                    Death Certificate  Cancer
#
#                                                  Question  Response  \
# 814932    Invasive cancer (all sites combined), mortality       NaN
# 814933  Invasive cancer of the oral cavity or pharynx,...       NaN
# ...

# %%
df.describe()
# Out:
#            YearStart        YearEnd  Response  DataValueAlt  \
# count  814937.000000  814937.000000       0.0  5.541390e+05
# mean     2013.706901    2014.152359       NaN  9.521159e+02
# std         2.570022       2.210645       NaN  1.912805e+04
# min      2001.000000    2001.000000       NaN  0.000000e+00
# 25%      2012.000000    2012.000000       NaN  1.750000e+01
# 50%      2014.000000    2014.000000       NaN  4.100000e+01
# 75%      2016.000000    2016.000000       NaN  7.480000e+01
# max      2018.000000    2018.000000       NaN  2.892731e+06
#
#        LowConfidenceLimit  HighConfidenceLimit  StratificationCategory2  \
# count       475125.000000        475125.000000                      0.0
# mean            50.774647            62.879506                      NaN
# std             87.282746            98.383594                      NaN
# min              0.000000             0.300000                      NaN
# ...

# %% [markdown]
# # Below I used groupby to see all topics that were captured

# %%
df.groupby(['Topic'])['LocationDesc'].max()
# Out:
# Topic
# Alcohol                                            Wyoming
# Arthritis                                          Wyoming
# Asthma                                             Wyoming
# Cancer                                             Wyoming
# Cardiovascular Disease                             Wyoming
# Chronic Kidney Disease                             Wyoming
# Chronic Obstructive Pulmonary Disease              Wyoming
# Diabetes                                           Wyoming
# Disability                                         Wyoming
# Immunization                                       Wyoming
# Mental Health                                      Wyoming
# Nutrition, Physical Activity, and Weight Status    Wyoming
# Older Adults                                       Wyoming
# Oral Health                                        Wyoming
# Overarching Conditions                             Wyoming
# Reproductive Health                                Wyoming
# ...

# %% [markdown]
# # Based on the groupby, I grouped by topic and count of each per state, based on end year - this allowed me to see what topics each state encounters.

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)
df.groupby(['Topic', 'LocationDesc'])['YearEnd'].sum()
# Out:
# Topic                                            LocationDesc
# Alcohol                                          Alabama                 1752440
#                                                  Alaska                  1794727
#                                                  Arizona                 1724237
#                                                  Arkansas                1780629
#                                                  California              1724237
#                                                  Colorado                1780629
#                                                  Connecticut             1766552
#                                                  Delaware                1794727
#                                                  District of Columbia    1724237
#                                                  Florida                 1724237
#                                                  Georgia                 1752412
# ...

# %%
df.groupby(['Topic','YearEnd'])['LocationDesc'].count()
# Out:
# Topic                                            YearEnd
# Alcohol                                          2010        1282
#                                                  2011        5467
#                                                  2012        5839
#                                                  2013        6124
#                                                  2014        5718
#                                                  2015        6362
#                                                  2016        5677
#                                                  2017        6399
#                                                  2018        4130
# Arthritis                                        2011        8700
#                                                  2012        5220
#                                                  2013        8700
#                                                  2014        5220
# ...

# %% [markdown]
# # Based on the topics, I then filtered out further to better understand how arthritis is evident in each state

# %%
df1=df[df['Topic'] == 'Arthritis']
df1

# %%
df1.head()
# Out:
#       YearStart  YearEnd LocationAbbr LocationDesc DataSource      Topic  \
# 813        2013     2013           MS  Mississippi      BRFSS  Arthritis
# 1419       2015     2015           AZ      Arizona      BRFSS  Arthritis
# 3985       2018     2018           GU         Guam      BRFSS  Arthritis
# 4355       2018     2018           TN    Tennessee      BRFSS  Arthritis
# 4769       2018     2018           PR  Puerto Rico      BRFSS  Arthritis
#
#                                                Question  Response  \
# 813   Fair or poor health among adults aged >= 18 ye...       NaN
# 1419            Arthritis among adults aged >= 18 years       NaN
# 3985  Arthritis among adults aged >= 18 years who ar...       NaN
# 4355            Arthritis among adults aged >= 18 years       NaN
# 4769            Arthritis among adults aged >= 18 years       NaN
#
#      DataValueUnit            DataValueType DataValue  DataValueAlt  \
# ...

# %% [markdown]
# # I then found that arthritis has a varied presence across states from 2011-2018

# %%
df1.groupby(['Topic','YearEnd'])['LocationDesc'].count()
# Out:
# Topic      YearEnd
# Arthritis  2011       8700
#            2012       5220
#            2013       8700
#            2014       5220
#            2015       8700
#            2016       5220
#            2017       7830
#            2018       5220
# Name: LocationDesc, dtype: int64

# %% [markdown]
# # The histogram below shows this variation

# %%
fig, ax = plt.subplots()
ax.hist(df1['YearEnd'])
# Out:
# (array([8700., 5220., 8700.,    0., 5220., 8700.,    0., 5220., 7830.,
#         5220.]),
#  array([2011. , 2011.7, 2012.4, 2013.1, 2013.8, 2014.5, 2015.2, 2015.9,
#         2016.6, 2017.3, 2018. ]),
#  <a list of 10 Patch objects>)
